# %%
import pandas as pd
fiatdf = pd.read_csv('fiat500.csv')
fiatdf9 = pd.read_csv('fiat50022.csv')

# %%
print(fiatdf.to_string())
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners        lat        lon  price
# 0        1  lounge            51          882   25000                1  44.907242   8.611560   8900
# 1        2     pop            51         1186   32500                1  45.666359  12.241890   8800
# 2        3   sport            74         4658  142228                1  45.503300  11.417840   4200
# 3        4  lounge            51         2739  160000                1  40.633171  17.634609   6000
# 4        5     pop            73         3074  106880                1  41.903221  12.495650   5700
# 5        6     pop            74         3623   70225                1  45.000702   7.682270   7900
# 6        7  lounge            51          731   11600                1  44.907242   8.611560  10750
# 7        8  lounge            51         1521   49076                1  41.903221  12.495650   9190
# ...

# %%
fiatdf.describe()
# Out:
#                 ID  engine_power  age_in_days             km  previous_owners  \
# count  1538.000000   1538.000000  1538.000000    1538.000000      1538.000000
# mean    769.500000     51.904421  1650.980494   53396.011704         1.123537
# std     444.126671      3.988023  1289.522278   40046.830723         0.416423
# min       1.000000     51.000000   366.000000    1232.000000         1.000000
# 25%     385.250000     51.000000   670.000000   20006.250000         1.000000
# 50%     769.500000     51.000000  1035.000000   39031.000000         1.000000
# 75%    1153.750000     51.000000  2616.000000   79667.750000         1.000000
# max    1538.000000     77.000000  4658.000000  235000.000000         4.000000
#
#                lat          lon         price
# count  1538.000000  1538.000000   1538.000000
# mean     43.541361    11.563428   8576.003901
# std       2.133518     2.328190   1939.958641
# min      36.855839     7.245400   2500.000000
# ...

# %%
print(fiatdf.shape)
# Out:
# (1538, 9)

# %%
print(fiatdf.isna().sum())
# Out:
# ID                 0
# model              0
# engine_power       0
# age_in_days        0
# km                 0
# previous_owners    0
# lat                0
# lon                0
# price              0
# dtype: int64

# %%
fiatdetails = fiatdf.drop(columns=['ID','model','lat','lon'])
print(fiatdetails.corr())
# Out:
#                  engine_power  age_in_days        km  previous_owners  \
# engine_power         1.000000     0.319190  0.285495        -0.005030
# age_in_days          0.319190     1.000000  0.833890         0.075775
# km                   0.285495     0.833890  1.000000         0.097539
# previous_owners     -0.005030     0.075775  0.097539         1.000000
# price               -0.277235    -0.893328 -0.859373        -0.076274
#
#                     price
# engine_power    -0.277235
# age_in_days     -0.893328
# km              -0.859373
# previous_owners -0.076274
# price            1.000000

# %%
fiatdetails = fiatdf.drop(columns=['ID','model','lat','lon'])
print(fiatdetails.corr().to_string())
# Out:
#                  engine_power  age_in_days        km  previous_owners     price
# engine_power         1.000000     0.319190  0.285495        -0.005030 -0.277235
# age_in_days          0.319190     1.000000  0.833890         0.075775 -0.893328
# km                   0.285495     0.833890  1.000000         0.097539 -0.859373
# previous_owners     -0.005030     0.075775  0.097539         1.000000 -0.076274
# price               -0.277235    -0.893328 -0.859373        -0.076274  1.000000

# %%
fiatdf['model'].unique()
# Out:
# array(['lounge', 'pop', 'sport'], dtype=object)

# %%
-fiatdf9['model'].unique()
# Out:
# array(['lounge', 'pop', 'sport', 'pop1'], dtype=object)

# %%
dfsport = fiatdf.loc[fiatdf['model'] == 'sport'] #sonly sport will be taken in the model
print(dfsport['km'].max())
print(dfsport['km'].mean())
print(dfsport['km'].min())
print(dfsport.shape)
print(dfsport.to_string)
# Out:
# 190000
# 103382.80232558139
# 6200
# (86, 9)
# <bound method DataFrame.to_string of         ID  model  engine_power  age_in_days      km  previous_owners  \
# 2        3  sport            74         4658  142228                1
# 8        9  sport            73         4049   76000                1
# 9       10  sport            51         3653   89000                1
# 27      28  sport            51         3531  100000                1
# 33      34  sport            51         3927  140000                2
# ...    ...    ...           ...          ...     ...              ...
# 1498  1499  sport            51         1400   60000                1
# 1501  1502  sport            51         3774  161900                1
# 1504  1505  sport            51         4322   95000                1
# 1531  1532  sport            73         4505  127000                1
# 1533  1534  sport            51         3712  115280                1
#
#             lat       lon  price
# ...

# %%
dfsport1 = fiatdf.loc[fiatdf['model'] == 'pop']
dfsport2 = fiatdf.loc[fiatdf['model'] == 'lounge']

# %%
X = dfsport.drop(columns=['ID','engine_power','lat','lon','price','model'])
Y = dfsport['price']
print(X.to_string())
print(Y.to_string())
# Out:
#       age_in_days      km  previous_owners
# 2            4658  142228                1
# 8            4049   76000                1
# 9            3653   89000                1
# 27           3531  100000                1
# 33           3927  140000                2
# 38            790   43100                1
# 40           4139  119000                1
# 48           3684  160000                1
# 49           4596  107000                1
# 51            790   35000                1
# 53           3288   71900                1
# 67           4261  188000                1
# 77           2739   77149                3
# 81           4292  145000                3
# 95           4292  165600                1
# 97           2009   86000                2
# 114          4018  102000                1
# 132          3988  175000                1
# 148          4383   74000                1
# 172          4077  124000                1
# 214          3592   99180                1
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
ans = model.predict([[2190,70000,1]])
print(ans)
# Out:
# [8017.82458566]
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
n=input("Enter car type : ")
cartype = fiatdf.loc[fiatdf['model'] == 'n']
print(cartype.to_string)
